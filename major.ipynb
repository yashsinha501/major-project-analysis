# %%
import pandas as pd

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-b97b0358-fe50-4393-ad82-aed30da45131" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b97b0358-fe50-4393-ad82-aed30da45131">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['majorProject.csv']))
print(df)
# Out:
#    Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4
# 0         NaN              NaN        NaN        NaN               NaN
# 1         NaN              NaN        NaN        NaN               NaN
# 2        S.NO             NAME        CT1        CT2  UNIVERSITY MARKS
# 3           1       Yash Sinha         18          0                79
# 4           2    Arpita Tiwari         20         19                75
# 5           3      Lalit Kumar         10         16                72
# 6           4   Vibhuti Mishra         18         17                81
# 7           5     Vibha Mishra         12         14                71
# 8           6           Arnab          16         15                72
# 9           7  Prateek Mallick         19         20                82
# 10          8          Abhijit         11         14                67
# 11          9           Diskha         14         10                76
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df.columns = ['Sno.', 'Name', 'CT1', 'CT2','University']

# %%
df.drop(index=df.index[0:3])
# Out:
#    Sno.             Name CT1 CT2 University
# 3     1       Yash Sinha  18   0         79
# 4     2    Arpita Tiwari  20  19         75
# 5     3      Lalit Kumar  10  16         72
# 6     4   Vibhuti Mishra  18  17         81
# 7     5     Vibha Mishra  12  14         71
# 8     6           Arnab   16  15         72
# 9     7  Prateek Mallick  19  20         82
# 10    8          Abhijit  11  14         67
# 11    9           Diskha  14  10         76
# 12   10            Swati  16  17         70
# 13   11           Keshav  16  12         65
# 14   12     Yash Kashyap   8  11         61
# 15   13           Aaksah   5   7         52
# 16   14            Aditi   0  13         68
# 17   15            Sonam  10  14         63
# 18   16           Ankush   4  10         52
# 19   17      Prathytusha  20   0         83
# 20   18          shristy  13  17         64
# 21   19          Sarthak  16  12         52
# 22   20        Dhirendra  10   0         57
